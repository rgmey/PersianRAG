# %%
import pandas as pd
df_main = pd.read_excel("../sample_data_dictionary.xlsx", sheet_name=None)

# %%
# python -m ipykernel install --user --name main_venv --display-name "main_venv Kernel"

# %%
df_main.keys()
# Out:
# dict_keys(['data_dictionary', 'CUSTOMER', 'ACCOUNT', 'TRANSACTION', 'LOAN', 'BRANCH', 'DEPOSIT', 'PAYMENT'])

# %%
df_main['data_dictionary']
# Out:
#      Table Name       Column Name      Data Type  \
# 0      CUSTOMER       customer_id            INT
# 1      CUSTOMER        first_name    VARCHAR(50)
# 2      CUSTOMER         last_name    VARCHAR(50)
# 3      CUSTOMER     date_of_birth           DATE
# 4      CUSTOMER            gender        CHAR(1)
# 5      CUSTOMER             email   VARCHAR(100)
# 6      CUSTOMER         join_date           DATE
# 7       ACCOUNT        account_id            INT
# 8       ACCOUNT       customer_id            INT
# 9       ACCOUNT      account_type    VARCHAR(20)
# 10      ACCOUNT         open_date           DATE
# 11      ACCOUNT           balance  DECIMAL(15,2)
# 12      ACCOUNT            status    VARCHAR(10)
# 13  TRANSACTION    transaction_id         BIGINT
# 14  TRANSACTION        account_id            INT
# 15  TRANSACTION  transaction_date       DATETIME
# 16  TRANSACTION  transaction_type    VARCHAR(20)
# 17  TRANSACTION            amount  DECIMAL(15,2)
# ...

# %%
df_main['PAYMENT']
# Out:
#   Table Name     Column Name      Data Type  \
# 0    PAYMENT      payment_id         BIGINT
# 1    PAYMENT      account_id            INT
# 2    PAYMENT  recipient_name   VARCHAR(100)
# 3    PAYMENT    payment_date       DATETIME
# 4    PAYMENT          amount  DECIMAL(15,2)
# 5    PAYMENT    payment_type    VARCHAR(30)
# 6    PAYMENT          status    VARCHAR(15)
#
#                                    Description Primary Key  \
# 0           Unique identifier for each payment         Yes
# 1      Account from which the payment was made         NaN
# 2                Name of the payment recipient         NaN
# 3                     Date and time of payment         NaN
# 4                                  Amount paid         NaN
# 5  Type of payment (Bill, Transfer, Loan, Tax)         NaN
# 6      Payment status (Success/Failed/Pending)         NaN
#
#           Foreign Key         Example Data
# 0                 NaN            800123456
# ...

# %%
df_main
# Out:
# {'data_dictionary':      Table Name       Column Name      Data Type  \
#  0      CUSTOMER       customer_id            INT
#  1      CUSTOMER        first_name    VARCHAR(50)
#  2      CUSTOMER         last_name    VARCHAR(50)
#  3      CUSTOMER     date_of_birth           DATE
#  4      CUSTOMER            gender        CHAR(1)
#  5      CUSTOMER             email   VARCHAR(100)
#  6      CUSTOMER         join_date           DATE
#  7       ACCOUNT        account_id            INT
#  8       ACCOUNT       customer_id            INT
#  9       ACCOUNT      account_type    VARCHAR(20)
#  10      ACCOUNT         open_date           DATE
#  11      ACCOUNT           balance  DECIMAL(15,2)
#  12      ACCOUNT            status    VARCHAR(10)
#  13  TRANSACTION    transaction_id         BIGINT
#  14  TRANSACTION        account_id            INT
#  15  TRANSACTION  transaction_date       DATETIME
#  16  TRANSACTION  transaction_type    VARCHAR(20)
# ...
